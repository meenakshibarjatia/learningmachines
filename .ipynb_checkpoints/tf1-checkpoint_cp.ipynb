# %%
import tensorflow as tf

# %%
from datetime import datetime
now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)

# %%
x = tf.Variable(1, 'x')
y = tf.Variable(1, 'y')
f = x*x*y + y + 2

sess = tf.Session()
sess.run(x.initializer)
sess.run(y.initializer)
result = sess.run(f)
print(result)

sess.close()
# Out:
# 4

# %%
init = tf.global_variables_initializer()

with tf.Session() as sess:
    init.run()
    result = f.eval()
    
print(result)
# Out:
# 4

# %%
import numpy as np
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
m, n = housing.data.shape
housingbias = np.c_[np.ones((m,1)), housing.data]

X = tf.constant(housingbias, dtype = tf.float32, name = 'X')
y = tf.constant(housing.target.reshape(-1, 1), dtype = tf.float32, name = 'y')
XT = tf.transpose(X)
theta = tf.matmul(tf.matmul(tf.matrix_inverse(tf.matmul(XT, X)), XT), y)

with tf.Session() as sess:
    theta_value = theta.eval()

# %%
from sklearn.preprocessing import StandardScaler

stdscale = StandardScaler()
scaled_housingbias = stdscale.fit_transform(housingbias)

# %%
n_epochs = 1000
learning_rate = 0.01

X = tf.constant(scaled_housingbias, dtype = tf.float32, name = 'X')
y = tf.constant(housing.target.reshape(-1, 1), dtype = tf.float32, name = 'y')
theta = tf.Variable(tf.random_uniform([n+1, 1], -1, 1), name = 'theta')
y_pred = tf.matmul(X, theta, name = "pred")
error = y_pred - y
mse = tf.reduce_mean(tf.square(error), name = "mse")
gradients = 2/m*tf.matmul(tf.transpose(X), error)
tr_op = tf.assign(theta, theta - learning_rate*gradients)

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(n_epochs):
        if epoch % 100 == 0:
            print("epoch :", epoch," mse = ", mse.eval())
        sess.run(tr_op)
        
    best_theta = theta.eval()
# Out:
# epoch : 0  mse =  7.79229
# epoch : 100  mse =  5.01652
# epoch : 200  mse =  4.94155
# epoch : 300  mse =  4.90366
# epoch : 400  mse =  4.8765
# epoch : 500  mse =  4.85677
# epoch : 600  mse =  4.84244
# epoch : 700  mse =  4.832
# epoch : 800  mse =  4.82439
# epoch : 900  mse =  4.81883

# %%
n_epochs = 1000
learning_rate = 0.01

X = tf.constant(scaled_housingbias, dtype = tf.float32, name = 'X')
y = tf.constant(housing.target.reshape(-1, 1), dtype = tf.float32, name = 'y')
theta = tf.Variable(tf.random_uniform([n+1, 1], -1, 1), name = 'theta')
y_pred = tf.matmul(X, theta, name = "pred")
error = y_pred - y
mse = tf.reduce_mean(tf.square(error), name = "mse")
optimizer = tf.train.GradientDescentOptimizer(learning_rate = learning_rate)
tr_op = optimizer.minimize(mse)

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(n_epochs):
        if epoch % 100 == 0:
            print("epoch :", epoch," mse = ", mse.eval())
        sess.run(tr_op)
        
    best_theta = theta.eval()
# Out:
# epoch : 0  mse =  8.45429
# epoch : 100  mse =  5.1513
# epoch : 200  mse =  5.01685
# epoch : 300  mse =  4.95619
# epoch : 400  mse =  4.91353
# epoch : 500  mse =  4.88281
# epoch : 600  mse =  4.86065
# epoch : 700  mse =  4.84466
# epoch : 800  mse =  4.83314
# epoch : 900  mse =  4.82481

# %%
batch_size = 100
n_batches = int(np.ceil(m/batch_size))

def fetch_batch(epoch, batch_ind, batch_sz):
    np.random.seed(epoch*n_batches + batch_ind)
    indices = np.random.randint(m, size = batch_sz)
    X_batch = scaled_housingbias[indices]
    y_batch = housing.target.reshape(-1, 1)[indices]
    return X_batch, y_batch

X = tf.placeholder(tf.float32, shape = (None, n+1), name = 'X')
y = tf.placeholder(tf.float32, shape = (None, 1), name = 'y')

theta = tf.Variable(tf.random_uniform([n+1, 1], -1, 1), name = 'theta')
y_pred = tf.matmul(X, theta, name = "pred")
error = y_pred - y
mse = tf.reduce_mean(tf.square(error), name = "mse")
optimizer = tf.train.GradientDescentOptimizer(learning_rate = learning_rate)
tr_op = optimizer.minimize(mse)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(n_epochs):
        for batch_ind in range(n_batches):
            X_batch, y_batch = fetch_batch(epoch, batch_ind, batch_size)
            sess.run(tr_op, feed_dict = {X: X_batch, y: y_batch})
            if (epoch % 100 == 0) & (batch_ind % 10 == 0):
                print("epoch :", epoch," mse = ", mse.eval(feed_dict = {X: X_batch, y: y_batch}))
    best_theta = theta.eval()
    save_path = saver.save("tmp/tf1.ckpt")
# Out:
# epoch : 0  mse =  5.31713
# epoch : 0  mse =  4.85919
# epoch : 0  mse =  5.12811
# epoch : 0  mse =  4.55895
# epoch : 0  mse =  5.35109
# epoch : 0  mse =  4.61044
# epoch : 0  mse =  4.96247
# epoch : 0  mse =  4.47759
# epoch : 0  mse =  4.44537
# epoch : 0  mse =  4.86644
# epoch : 0  mse =  5.27621
# epoch : 0  mse =  4.59167
# epoch : 0  mse =  4.49415
# epoch : 0  mse =  4.85247
# epoch : 0  mse =  4.05271
# epoch : 0  mse =  5.07899
# epoch : 0  mse =  4.44189
# epoch : 0  mse =  4.34449
# epoch : 0  mse =  5.22623
# epoch : 0  mse =  4.85044
# epoch : 0  mse =  4.46965
# epoch : 100  mse =  4.91849
# epoch : 100  mse =  4.44628
# epoch : 100  mse =  4.70199
# epoch : 100  mse =  5.08787
# epoch : 100  mse =  5.21794
# epoch : 100  mse =  5.34566
# epoch : 100  mse =  3.88427
# epoch : 100  mse =  4.68632
# epoch : 100  mse =  5.09016
# epoch : 100  mse =  4.43382
# epoch : 100  mse =  4.97779
# epoch : 100  mse =  4.72559
# epoch : 100  mse =  5.37527
# epoch : 100  mse =  4.53078
# epoch : 100  mse =  4.59255
# epoch : 100  mse =  5.72831
# epoch : 100  mse =  4.78588
# epoch : 100  mse =  4.88218
# epoch : 100  mse =  5.29018
# epoch : 100  mse =  4.16494
# epoch : 100  mse =  4.3542
# epoch : 200  mse =  5.19973
# epoch : 200  mse =  4.51869
# epoch : 200  mse =  4.51971
# epoch : 200  mse =  4.85144
# epoch : 200  mse =  4.84243
# epoch : 200  mse =  4.45756
# epoch : 200  mse =  5.3443
# epoch : 200  mse =  5.04829
# epoch : 200  mse =  4.53707
# epoch : 200  mse =  4.52599
# epoch : 200  mse =  5.09145
# epoch : 200  mse =  4.94616
# epoch : 200  mse =  4.6267
# epoch : 200  mse =  4.86466
# epoch : 200  mse =  4.88491
# epoch : 200  mse =  4.42745
# epoch : 200  mse =  4.69058
# epoch : 200  mse =  4.24806
# epoch : 200  mse =  5.15013
# epoch : 200  mse =  4.60557
# epoch : 200  mse =  4.62473
# epoch : 300  mse =  4.48736
# epoch : 300  mse =  4.68154
# epoch : 300  mse =  5.84533
# epoch : 300  mse =  5.26435
# epoch : 300  mse =  5.22431
# epoch : 300  mse =  4.55503
# epoch : 300  mse =  3.98828
# epoch : 300  mse =  4.25753
# epoch : 300  mse =  4.6944
# epoch : 300  mse =  4.08718
# epoch : 300  mse =  4.88823
# epoch : 300  mse =  4.71995
# epoch : 300  mse =  4.64599
# epoch : 300  mse =  4.99541
# epoch : 300  mse =  4.27341
# epoch : 300  mse =  4.9908
# epoch : 300  mse =  5.19408
# epoch : 300  mse =  5.10034
# epoch : 300  mse =  4.77688
# epoch : 300  mse =  4.91308
# epoch : 300  mse =  4.73811
# epoch : 400  mse =  5.60045
# epoch : 400  mse =  4.85781
# epoch : 400  mse =  4.24256
# epoch : 400  mse =  5.14518
# epoch : 400  mse =  4.79285
# epoch : 400  mse =  4.68449
# epoch : 400  mse =  5.39117
# epoch : 400  mse =  4.71739
# epoch : 400  mse =  4.93631
# epoch : 400  mse =  5.24403
# epoch : 400  mse =  4.65885
# epoch : 400  mse =  4.66462
# epoch : 400  mse =  5.12861
# epoch : 400  mse =  5.13438
# epoch : 400  mse =  4.71924
# epoch : 400  mse =  5.42678
# epoch : 400  mse =  4.57922
# epoch : 400  mse =  4.71303
# epoch : 400  mse =  4.83465
# epoch : 400  mse =  5.26766
# epoch : 400  mse =  5.06484
# epoch : 500  mse =  4.7413
# epoch : 500  mse =  5.37487
# epoch : 500  mse =  5.23986
# epoch : 500  mse =  4.75532
# epoch : 500  mse =  4.35618
# epoch : 500  mse =  4.30582
# epoch : 500  mse =  4.25954
# epoch : 500  mse =  5.27026
# epoch : 500  mse =  4.85532
# epoch : 500  mse =  4.63702
# epoch : 500  mse =  4.91139
# epoch : 500  mse =  8.57286
# epoch : 500  mse =  5.05097
# epoch : 500  mse =  4.70101
# epoch : 500  mse =  4.63696
# epoch : 500  mse =  4.74986
# epoch : 500  mse =  4.96217
# epoch : 500  mse =  4.71748
# epoch : 500  mse =  5.38851
# epoch : 500  mse =  5.38155
# epoch : 500  mse =  5.76053
# epoch : 600  mse =  4.37209
# epoch : 600  mse =  4.96702
# epoch : 600  mse =  5.04713
# epoch : 600  mse =  4.76292
# epoch : 600  mse =  5.03459
# epoch : 600  mse =  4.81617
# epoch : 600  mse =  4.47718
# epoch : 600  mse =  4.95958
# epoch : 600  mse =  5.19904
# epoch : 600  mse =  4.66446
# epoch : 600  mse =  5.13611
# epoch : 600  mse =  5.18085
# epoch : 600  mse =  4.87224
# epoch : 600  mse =  4.60926
# epoch : 600  mse =  4.56307
# epoch : 600  mse =  4.38509
# epoch : 600  mse =  4.20519
# epoch : 600  mse =  5.08194
# epoch : 600  mse =  4.70177
# epoch : 600  mse =  4.90853
# epoch : 600  mse =  4.69836
# epoch : 700  mse =  4.75503
# epoch : 700  mse =  4.66496
# epoch : 700  mse =  4.19726
# epoch : 700  mse =  4.38685
# epoch : 700  mse =  4.71385
# epoch : 700  mse =  4.43549
# epoch : 700  mse =  5.79411
# epoch : 700  mse =  4.94908
# epoch : 700  mse =  4.4694
# epoch : 700  mse =  4.75718
# epoch : 700  mse =  4.26535
# epoch : 700  mse =  4.91658
# epoch : 700  mse =  4.52976
# epoch : 700  mse =  4.53337
# epoch : 700  mse =  5.50929
# epoch : 700  mse =  5.13165
# epoch : 700  mse =  5.23695
# epoch : 700  mse =  5.37425
# epoch : 700  mse =  4.67764
# epoch : 700  mse =  4.37522
# epoch : 700  mse =  5.13068
# epoch : 800  mse =  4.49307
# epoch : 800  mse =  4.72951
# epoch : 800  mse =  5.05928
# epoch : 800  mse =  4.40885
# epoch : 800  mse =  4.29896
# epoch : 800  mse =  4.67369
# epoch : 800  mse =  5.49845
# epoch : 800  mse =  4.76874
# epoch : 800  mse =  4.59124
# epoch : 800  mse =  4.55869
# epoch : 800  mse =  5.33203
# epoch : 800  mse =  4.48825
# epoch : 800  mse =  4.99446
# epoch : 800  mse =  4.44256
# epoch : 800  mse =  4.69507
# epoch : 800  mse =  4.65207
# epoch : 800  mse =  4.75845
# epoch : 800  mse =  4.53421
# epoch : 800  mse =  4.65961
# epoch : 800  mse =  5.35853
# epoch : 800  mse =  4.75092
# epoch : 900  mse =  4.83
# epoch : 900  mse =  4.24932
# epoch : 900  mse =  4.15469
# epoch : 900  mse =  4.30213
# epoch : 900  mse =  4.50567
# epoch : 900  mse =  3.93617
# epoch : 900  mse =  4.94032
# epoch : 900  mse =  4.81361
# epoch : 900  mse =  5.24569
# epoch : 900  mse =  5.5377
# epoch : 900  mse =  5.22888
# epoch : 900  mse =  5.03829
# epoch : 900  mse =  4.93924
# epoch : 900  mse =  5.2326
# epoch : 900  mse =  4.87174
# epoch : 900  mse =  4.75991
# epoch : 900  mse =  5.22914
# epoch : 900  mse =  4.80666
# epoch : 900  mse =  4.35294
# epoch : 900  mse =  4.46691
# epoch : 900  mse =  5.16398
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-17-68e52d061699> in <module>()
#      32                 print("epoch :", epoch," mse = ", mse.eval(feed_dict = {X: X_batch, y: y_batch}))
#      33     best_theta = theta.eval()
# ---> 34     save_path = saver.save("tmp/tf1.ckpt")
#
# TypeError: save() missing 1 required positional argument: 'save_path'

# %%
X_batch, y_batch = fetch_batch(0, 0, batch_size)
print(X_batch.shape, y_batch.shape)
print(n)
# Out:
# (100, 9) (100, 1)
# 8
